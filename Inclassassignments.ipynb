# %% [markdown]
# <a href="https://colab.research.google.com/github/emmedemilt-bot/BTE320/blob/main/Inclassassignments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sales = float(input("Enter sales($): "))
rate = float (input("enter tax rate (%): "))

cogs = sales*0.4

GrossProfit= sales - cogs
taxes = rate * grossprofit
net = grossprofit - taxes

print(f"sales: {sales}$")
print(f"cost of goods sold: {cogs}$")
print(f"gross profit: {grossprofit}$")
