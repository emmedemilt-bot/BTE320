# %% [markdown]
# <a href="https://colab.research.google.com/github/emmedemilt-bot/BTE320/blob/main/bte3201K_Notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello')
# Out:
# Hello

# %%
1 x = 2
# Out:
#   File "/tmp/ipython-input-892805676.py", line 1
#     1 x = 2
#       ^
# SyntaxError: invalid syntax
